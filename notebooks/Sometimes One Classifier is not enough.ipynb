# %% [markdown]
# ## Learning Rate

# %% [markdown]
# lets take the x = 3 and y = 1 and then x = 1 and y = 3 and plot according to the equation
#
#                         ΔA = E / x
#
# what is happening here?

# %% [markdown]
# ### Figure  2.1
# ![example2-3.png](attachment:example2-3.png)

# %% [markdown]
# What this is not what we want? Each new observation the line is jumping directly to the desired value for that observation. This is what you would expect from our implemetation of our previous equation
#
#                     ΔA = E / x

# %% [markdown]
# What we need is some moderation with our updates. This is the beginning of one of the core idea of machine learning the learning rate. We use it to slowly nudge our updates in the right direction while not losing the all the data from the previous observation.
#
#                     ΔA = L x (E / x)
#
# Real training examples can contain noise and errors, it helps us lessen the effect they have our training.Now we will have a classifier that takes in account all the observations and classifies ladybirds and caterpillars accordingly.

# %% [markdown]
# ### Conclusion:
#
#     - Doing each new update naively makes us discard the previous observation data.
#     - Training examples can contain noise and errors. Moderation lessens their impact on our data.

# %% [markdown]
# ## Sometimes One Classifier is not enough

# %% [markdown]
# Using the basic predictor as a classifier is all good and all but what happens when the data is not goverend by a single linear function.Lets look towards Boolean function to explain such a case.

# %% [markdown]
# Boolean functions take 2 inputs and one output.

# %% [markdown]
# ![example3-1.png](attachment:example3-1.png)

# %% [markdown]
# Computers often represent true as 1, and false as 0.

# %% [markdown]
# ![example3.png](attachment:example3.png)

# %% [markdown]
# For logical AND, if we want to classify it into two separate classes we can make a dividing line as such, classifying the true from false

# %% [markdown]
# ![example3-3.png](attachment:example3-3.png)

# %% [markdown]
# Same is the case with OR function

# %% [markdown]
# ![example3-2.png](attachment:example3-2.png)

# %% [markdown]
# But what happens when XOR comes into the equation?

# %% [markdown]
# ![example4-1.png](attachment:example4-1.png)

# %% [markdown]
# The figure can't be classified using a single line

# %% [markdown]
# ![example4-2.png](attachment:example4-2.png)

# %% [markdown]
# In such a case, we need a fix. What would be the fix?
#
# It would be to use two seperate lines to classify different regions as shown below.

# %% [markdown]
# ![example4-3.png](attachment:example4-3.png)

# %% [markdown]
# This is where the idea of using multiple classifier comes in. This idea is also central to neural networks.

# %% [markdown]
# Conclusion:
#
#     - A single classifier cant classify the data if it is not governed by a single linear process.
#     - The fix is easy just use multiple classifiers.
